# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import cv2

# %%
r_img=cv2.imread('C:/Users/panindia/Desktop/Udemy/Computer-Vision-with-Python/DATA/reeses_puffs.png',0)

# %%
def display(img,cmap='gray'):
    fig=plt.figure(figsize=(12,10))
    ax=fig.add_subplot(111)
    ax.imshow(img,'gray')

# %%
c_img=cv2.imread('C:/Users/panindia/Desktop/Udemy/Computer-Vision-with-Python/DATA/many_cereals.jpg',0)

# %%
sift=cv2.xfeatures2d.SIFT_create()

# %%
kp1,dsp1=sift.detectAndCompute(r_img,None)
kp2,dsp2=sift.detectAndCompute(c_img,None)

# %%
FLANN_INDEX_KDTREE=0

index_params=dict(algorithm=FLANN_INDEX_KDTREE,trees=5)
search_params=dict(checks=50)

# %%
flann=cv2.FlannBasedMatcher(index_params,search_params)

# %%
match=flann.knnMatch(dsp1,dsp2,k=2)

# %%
good=[]


for match1,match2 in match:
    if match1.distance<0.7*match2.distance:
        good.append([match1])

# %%
detect=cv2.drawMatchesKnn(r_img,kp1,c_img,kp2,good,None,flags=2)

# %%
display(detect)
